# %%
#importing various packages
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.impute import KNNImputer

# %%
df=pd.read_csv('/content/Financial Analytics data.csv')

# %%
df.head(10)
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0      1  Reliance Inds.        583436.72           99810.00         NaN
# 1      2             TCS        563709.84           30904.00         NaN
# 2      3       HDFC Bank        482953.59           20581.27         NaN
# 3      4             ITC        320985.27            9772.02         NaN
# 4      5         H D F C        289497.37           16840.51         NaN
# 5      6  Hind. Unilever        288265.26            8590.00         NaN
# 6      7   Maruti Suzuki        263493.81           19283.20         NaN
# 7      8         Infosys        248320.35           17794.00         NaN
# 8      9         O N G C        239981.50           22995.88         NaN
# 9     10  St Bk of India        232763.33           57014.08         NaN

# %%
df.isna().sum()
# Out:
# S.No.                  0
# Name                   0
# Mar Cap - Crore        9
# Sales Qtr - Crore    123
# Unnamed: 4           394
# dtype: int64

# %%
df1=df

# %%
data = df1[['Mar Cap - Crore', 'Sales Qtr - Crore']]

# %%
imputer = KNNImputer(n_neighbors=5)

# %%
imputed_data = imputer.fit_transform(data)

# %%
df1[['Mar Cap - Crore', 'Sales Qtr - Crore']] = imputed_data

# %%
df1.sample(10)
# Out:
#      S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 374    387    Shoppers St.          4558.06           2041.358         NaN
# 290    303    Century Ply.          6966.23            509.930         NaN
# 224    231   Bombay Burmah         10864.53           2776.520         NaN
# 429    442            IFCI          3789.45            757.696      626.80
# 291    304       Blue Star          6952.99            981.300         NaN
# 253    264   Phoenix Mills          9097.33            416.610         NaN
# 29      30      Bajaj Fin.         94476.77           3540.630         NaN
# 240    247      Arvind Ltd         10247.70           2705.750         NaN
# 24      25  UltraTech Cem.        113692.87           8019.240         NaN
# 383    396   Essel Propack          4371.24           1925.112      595.05

# %%
sns.boxplot(data=df1, x='Mar Cap - Crore')
# Out:
# <Axes: xlabel='Mar Cap - Crore'>

# %%
sns.boxplot(data=df1, x='Sales Qtr - Crore')
# Out:
# <Axes: xlabel='Sales Qtr - Crore'>

# %%
#I will use IQR method to eliminate the outliers
#calculating first and third quartiles
Q1 = df1['Mar Cap - Crore'].quantile(0.25)
Q3 = df1['Mar Cap - Crore'].quantile(0.75)

# %%
#Calculating IQR
IQR = Q3-Q1

# %%
#defining lower and upper limits
lower = Q1-1.5*IQR
upper = Q3+1.5*IQR

# %%
df1 = df1[(df1['Mar Cap - Crore'] >= lower) & (df1['Mar Cap - Crore'] <= upper)]

# %%
sns.boxplot(data=df1, x='Mar Cap - Crore')
# Out:
# <Axes: xlabel='Mar Cap - Crore'>

# %%
df1.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# count  328.000000       328.000000         328.000000   57.000000
# mean   322.698171      7897.019024        1235.572634  454.456842
# std    105.292938      4556.226860         842.996007  265.432660
# min    134.000000      3017.070000          47.240000    0.000000
# 25%    231.750000      4190.555000         536.860000  185.650000
# 50%    324.500000      6351.870000         985.470000  473.420000
# 75%    412.250000     10848.097500        1903.383000  656.780000
# max    499.000000     20832.400000        3557.940000  969.100000

# %%
sns.boxplot(data=df1, x='Sales Qtr - Crore')
# Out:
# <Axes: xlabel='Sales Qtr - Crore'>

# %%
df1 = df1[(df1['Sales Qtr - Crore'] >= lower) & (df1['Sales Qtr - Crore'] <= upper)]

# %%
sns.boxplot(data=df1, x='Sales Qtr - Crore')
# Out:
# <Axes: xlabel='Sales Qtr - Crore'>
